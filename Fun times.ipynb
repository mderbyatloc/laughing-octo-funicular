# %% [markdown]
# # This is a heading
# * This is a bullet
# * this is the second bullet
# Regular text

# %% [markdown]
# ## This is a second heading
# * This is a bullet
# * this is a second bullet
#
# This is regular text

# %% [markdown]
# This is regular text
# this is regular text too
#
# this is a new line of text

# %%
print("This is some cool stuff")
# Out:
# This is some cool stuff

# %%
for 1 .. 99
    print("Is this how loops work")
# Out:
#   File "<ipython-input-3-59ddd5eebe01>", line 1
#     for 1 .. 99
#            ^
# SyntaxError: invalid syntax
