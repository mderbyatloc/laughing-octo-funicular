# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("http://decorlookalikes.com").content
soup = BeautifulSoup(page, 'html.parser')
page_title = soup.find('title').get_text()
print(page_title)
# Out:
# Decor Look Alikes | finding brand name looks at a price you can like
